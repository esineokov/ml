# %% [markdown]
# # Комментарии к ДЗ

# %% [markdown]
# ### 0. Бинарная классификация
# Смотрим на метрику (precision, recall, f1) целевого класса (таргет=1)
#
# **Note**
# - precision, recall, f-score зависят от порога вероятности
# - roc-auc - не зависит

# %% [markdown]
# ### 1. Обобщение метрик для мультиклассовых задач

# %% [markdown]
# (!) precision, recall, f-score - можно обобщить
# (!) ROC-AUC - нельзя обобщить

# %% [markdown]
# micro, macro, weighted f1_score, см [документацию](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html) к sklearn

# %%
import numpy as np

# 3 класса
TP1, TN1, FP1, FN1 = 3, 4, 1, 2   # 5
TP2, TN2, FP2, FN2 = 2, 4, 3, 1   # 3
TP3, TN3, FP3, FN3 = 2, 4, 2, 0   # 2

# %% [markdown]
# **Micro**
# Когда важно общее качество классификатора + нет сильного дисбаланса классов

# %%
# Micro

TP = TP1 + TP2 + TP3
FP = FP1 + FP2 + FP3

precison_micro = TP / (TP + FP)
precison_micro

# %% [markdown]
# **Macro**
# Когда каждый класс одинаково важен. Пример - классификация рукописных цифр

# %%
# Macro

PR1 = TP1 / (TP1 + FP1)
PR2 = TP2 / (TP2 + FP2)
PR3 = TP3 / (TP3 + FP3)

precison_macro = np.mean([PR1, PR2, PR3])
precison_macro

# %% [markdown]
# **Weighted**
# Когда более важно классифицировать более крупные классы. Пример - классификации кухни мира (Итальянская, Французская, ..) по фото блюда

# %%
# weighted by number of True labels in class

precison_weighted = (5*PR1 + 3*PR2 + 2*PR3) / (5 + 3 + 2)
precison_weighted

# %% [markdown]
# ### 2. LightGBM vs CatBoost vs XGBoost

# %% [markdown]
# См [статью](https://towardsdatascience.com/catboost-vs-light-gbm-vs-xgboost-5f93620723db)

# %% [markdown]
# **XGBoost**
# - Depth-wise boosting
# - Поддерживает ограничение на монотонность
#
#
# **LightGBM**
# - Leaf-wise boosting
# - Поддерживает категориальные фичи (categorical_features = ['feature_1', 'feature_2])
# - Поддерживает ограничение на монотонность
# - Пожалуй, самый быстрый
#
# **CatBoost**
# - Leaf-wise boosting
# - Поддерживает категориальные фичи
# - Поддерживает текстовые фичи
# - Очень много параметров - гибкий, но сложно тюнить
# - Пожалуй, наиболее подхожящий для продакшн (если уметь очень хорошо настраивать праметры)
#
#
# Depth-wise boosting --> тюним max_depth (3-7)
# Leaf-wise boosting --> тюним max_leafes при адекватном ограничениее на max_depth (5-15)

# %% [markdown]
# ## Урок 4.
# # Способы улучшения полученной модели.
#
# **План занятия**
#
# * [Теоретическая часть](#theory)
#     * [Переобучение и способы борьбы с ним](#overfitting)
#     * [Регуляризация](#regularization)
# * [Практическая часть](#practice)
#     * [Загрузка подготовленных датасетов](#data_loading)
#     * [Модель, полученная на предыдущем уроке](#model_from_prev_lesson)
#     * [Снижение степени переобучения](#lowering_overfitting)
#     * [Подбор оптимального размера выборки, кривая обучения](#learning_curve)
#     * [Выбор порога вероятности для определения класса](#threshold_calibration)
#     * [Важность признаков](#feature_importances)
#     * [Финальная модель](#final_model)
#     * [Сохранение финальной модели](#final_model_saving)

# %% [markdown]
# ## <center>Теоретическая часть<a class="anchor" id="theory"></a><center>

# %% [markdown]
# ### Переобучение и способы борьбы с ним<a class="anchor" id="overfitting"></a>

# %%
#ROC-AUC
#ROC-AUC = 50 -> random

# 1 : 95% train, 90% test
# 2 : 60% train, 55% test


# 5-10%: F1_train = 70, F1_test = 63-67

# %% [markdown]
# **Переобучение**
#
# Нежелательное явление, возникающее при решении задач обучения по прецедентам, когда вероятность ошибки обученного алгоритма на объектах тестовой выборки оказывается существенно выше, чем средняя ошибка на обучающей выборке. Переобучение возникает при использовании избыточно сложных моделей.

# %% [markdown]
# <img src="overfitting.svg" alt="Drawing" style="width: 500px;">

# %% [markdown]
# **Способы борьбы с переобучением**
#
# 1. Обнаружить переобучение:
#     * отложенная выборка
#     * кросс-валидация
#     * меры сложности модели (AIC, BIC)
# 2. Взять больше данных
# 3. Выбрать более простую медель
# 4. Регуляризация

# %% [markdown]
# ### Регуляризация<a class="anchor" id="regularization"></a>

# %% [markdown]
# Регуляризация - метод борьбы с переобучением, с помощью добавления некоторого штрафа за сложность модели.

# %% [markdown]
# <img src="bias.png" alt="Drawing" style="width: 500px;">

# %%
# 5000 - ошибка при использовании эвристики
# 4500 - использование линейной модели
# случайный лес - 3800
# градиентный бустинг - 3400

# %% [markdown]
# **Bias-Variance trade-off**
#
# - Variance (числопараметров модели, глубина дерева) снижается --> растет bias
# - Всегда можно найти модель с регуляризацией, которая точнее чем модель без регуляризации
# - *Всегда используйте регуляризцию!*

# %% [markdown]
# ### Линейная регрессия
#
# $$y_{pred} = w_0 + w_1*x_1 + w_2*x_2$$
#
# $\large L_1 = \sum_{i=1} (y_i - \widehat{y_i})^2$

# %% [markdown]
# **L1-регуляризация** (lasso, регуляризация через манхэттенское расстояние)
#
# $\large L_1 = \sum_{i=1} (y_i - \widehat{y_i})^2 + \lambda\sum_{j=1} |w_j|$
# - Зануляет веся $w_i$ = отбор фичей

# %% [markdown]
# **L2-регуляризация** (ridge, регуляризация Тихонова)
#
# $\large L_2 = \sum_{i=1} (y_i - \widehat{y_i})^2 + \lambda\sum_{j=1} w_j^2$
# - Обучается быстрее чем L1

# %% [markdown]
# ## <center>Практическая часть<a class="anchor" id="practice"></a><center>

# %% [markdown]
# **Подключение библиотек и скриптов**

# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.model_selection import train_test_split, ShuffleSplit, cross_val_score, learning_curve
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV
import xgboost as xgb
import catboost as catb

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def get_classification_report(y_train_true, y_train_pred, y_test_true, y_test_pred):
    print('TRAIN\n\n' + classification_report(y_train_true, y_train_pred))
    print('TEST\n\n' + classification_report(y_test_true, y_test_pred))
    print('CONFUSION MATRIX\n')
    print(pd.crosstab(y_test_true, y_test_pred))

# %%
def show_proba_calibration_plots(y_predicted_probs, y_true_labels):
    preds_with_true_labels = np.array(list(zip(y_predicted_probs, y_true_labels)))

    thresholds = []
    precisions = []
    recalls = []
    f1_scores = []

    for threshold in np.linspace(0.1, 0.9, 9):
        thresholds.append(threshold)
        precisions.append(precision_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))
        recalls.append(recall_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))
        f1_scores.append(f1_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))

    scores_table = pd.DataFrame({'f1':f1_scores,
                                 'precision':precisions,
                                 'recall':recalls,
                                 'probability':thresholds}).sort_values('f1', ascending=False).round(3)
  
    figure = plt.figure(figsize = (15, 5))

    plt1 = figure.add_subplot(121)
    plt1.axhline(0.5, color="red")
    plt1.plot(thresholds, precisions, label='Precision', linewidth=4)
    plt1.plot(thresholds, recalls, label='Recall', linewidth=4)
    plt1.plot(thresholds, f1_scores, label='F1', linewidth=4)
    plt1.set_ylabel('Scores')
    plt1.set_xlabel('Probability threshold')
    plt1.set_title('Probabilities threshold calibration')
    plt1.legend(bbox_to_anchor=(0.25, 0.25))   
    plt1.table(cellText = scores_table.values,
               colLabels = scores_table.columns, 
               colLoc = 'center', cellLoc = 'center', loc = 'bottom', bbox = [0, -1.3, 1, 1])

    plt2 = figure.add_subplot(122)
    plt2.hist(preds_with_true_labels[preds_with_true_labels[:, 1] == 0][:, 0], 
              label='Another class', color='royalblue', alpha=1)
    plt2.hist(preds_with_true_labels[preds_with_true_labels[:, 1] == 1][:, 0], 
              label='Main class', color='darkcyan', alpha=0.8)
    plt2.set_ylabel('Number of examples')
    plt2.set_xlabel('Probabilities')
    plt2.set_title('Probability histogram')
    plt2.legend(bbox_to_anchor=(1, 1))

    plt.show()

# %%
def show_learning_curve_plot(estimator, X, y, cv=3, n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):

    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, 
                                                            cv=cv, 
                                                            scoring='f1',
                                                            train_sizes=train_sizes, 
                                                            n_jobs=n_jobs)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.figure(figsize=(15,8))
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.title(f"Learning curves ({type(estimator).__name__})")
    plt.xlabel("Training examples")
    plt.ylabel("Score")     
    plt.legend(loc="best")
    plt.grid()
    plt.show()

# %%
def show_feature_importances(feature_names, feature_importances, get_top=None):
    feature_importances = pd.DataFrame({'feature': feature_names, 'importance': feature_importances})
    feature_importances = feature_importances.sort_values('importance', ascending=False)
       
    plt.figure(figsize = (20, len(feature_importances) * 0.355))
    
    sns.barplot(feature_importances['importance'], feature_importances['feature'])
    
    plt.xlabel('Importance')
    plt.title('Importance of features')
    plt.show()

    if get_top is not None:
        return feature_importances['feature'][:get_top].tolist()

# %% [markdown]
# **Пути к директориям и файлам**

# %%
# input
PREP_DATASET_PATH = '../Python_libs2_course_project/training_project_data_prep.csv'

# output
MODEL_FILE_PATH = '../models/model.pkl'

# %% [markdown]
# ### Загрузка подготовленных датасетов<a class="anchor" id="data_loading"></a>

# %% [markdown]
# **Загрузка данных**

# %%
df = pd.read_csv(PREP_DATASET_PATH)

# %% [markdown]
# **Выделение признакового описания и целевой переменной**

# %%
TARGET_NAME = 'NEXT_MONTH_DEFAULT'
FEATURE_NAMES_SELECTED = ['LIMIT_BAL',
 'AGE',
 'BILL_AMT1',
 'BILL_AMT2',
 'BILL_AMT3',
 'BILL_AMT4',
 'BILL_AMT5',
 'BILL_AMT6',
 'PAY_AMT1',
 'PAY_AMT2',
 'PAY_AMT3',
 'PAY_AMT4',
 'PAY_AMT5',
 'PAY_AMT6',
 'IS_MALE',
 'EDUCATION_1',
 'EDUCATION_2',
 'EDUCATION_3',
 'EDUCATION_4',
 'EDUCATION_5',
 'EDUCATION_6',
 'MARRIAGE_1',
 'MARRIAGE_2',
 'MARRIAGE_3',
 'PAY_1_-1',
 'PAY_1_0',
 'PAY_1_1',
 'PAY_1_2',
 'PAY_1_3',
 'PAY_2_-1',
 'PAY_2_0',
 'PAY_2_1',
 'PAY_2_2',
 'PAY_2_3',
 'PAY_3_-1',
 'PAY_3_0',
 'PAY_3_1',
 'PAY_3_2',
 'PAY_3_3',
 'PAY_4_-1',
 'PAY_4_0',
 'PAY_4_2',
 'PAY_4_3',
 'PAY_5_-1',
 'PAY_5_0',
 'PAY_5_2',
 'PAY_5_3',
 'PAY_6_-1',
 'PAY_6_0',
 'PAY_6_2',
 'PAY_6_3']

# %%
X = df[FEATURE_NAMES_SELECTED]
y = df[TARGET_NAME]

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.25, random_state=211)

# %% [markdown]
# ### Модель, полученная на предыдущем уроке<a class="anchor" id="model_from_prev_lesson"></a>

# %%
final_model = catb.CatBoostClassifier(n_estimators=500, max_depth=3, silent=True, random_state=21)
final_model.fit(X_train, y_train)

y_train_pred = final_model.predict(X_train)
y_test_pred = final_model.predict(X_test)
y_test_pred_probs = final_model.predict_proba(X_test)

get_classification_report(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      5852
#            1       0.73      0.40      0.51      1648
#
#     accuracy                           0.83      7500
#    macro avg       0.79      0.68      0.71      7500
# weighted avg       0.82      0.83      0.82      7500
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      1953
#            1       0.70      0.36      0.48       547
#
#     accuracy                           0.83      2500
#    macro avg       0.77      0.66      0.69      2500
# weighted avg       0.81      0.83      0.81      2500
#
# CONFUSION MATRIX
#
# col_0                  0    1
# NEXT_MONTH_DEFAULT
# 0                   1869   84
# 1                    348  199

# %%
FN

# %% [markdown]
# ### Снижение степени переобучения<a class="anchor" id="lowering_overfitting"></a>

# %%
final_model = catb.CatBoostClassifier(n_estimators=500, max_depth=3, l2_leaf_reg=10, silent=True, random_state=21)
final_model.fit(X_train, y_train)

y_train_pred = final_model.predict(X_train)
y_test_pred = final_model.predict(X_test)
y_test_pred_probs = final_model.predict_proba(X_test)

get_classification_report(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      5852
#            1       0.70      0.37      0.48      1648
#
#     accuracy                           0.83      7500
#    macro avg       0.77      0.66      0.69      7500
# weighted avg       0.81      0.83      0.81      7500
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      1953
#            1       0.71      0.36      0.48       547
#
#     accuracy                           0.83      2500
#    macro avg       0.78      0.66      0.69      2500
# weighted avg       0.81      0.83      0.81      2500
#
# CONFUSION MATRIX
#
# col_0                  0    1
# NEXT_MONTH_DEFAULT
# 0                   1874   79
# 1                    349  198

# %% [markdown]
# ### Подбор оптимального размера выборки, кривая обучения<a class="anchor" id="learning_curve"></a>

# %%
final_model = catb.CatBoostClassifier(n_estimators=500, max_depth=3, l2_leaf_reg=10,
                                      silent=True, random_state=21)

# %%
# CAPACITY
show_learning_curve_plot(final_model, X, y)

# %% [markdown]
# - Смотрим разницу train/test
# - Смотрим вышла ли нв плато кривая обучения на test:
# -- Если нет, можно собрать больше данных и увеличить скор
# -- Если да, то все хорошо. Но если модель учится СЛИШКОМ долго, то можно просто выбросить часть данных --> станет учиться быстрее

# %% [markdown]
# ### Выбор порога вероятности для определения класса<a class="anchor" id="threshold_calibration"></a>

# %% [markdown]
# (!) Модель НЕ меняется

# %% [markdown]
# - прогнозная вероятность > 50% --> 1
# - прогнозная вероятность > 30% --> 1

# %%
# model = ...
# model.fit
# y_pred_proba = model.predict_proba
# 0.12, 0.46, 0.75, 0.5, 0.9, ....

# 1 / 0

# по дефолту
# 0, 0, 1, 0, 1

# порог = 0.3
# 0, 1, 1, 0, 1

# %%
final_model.fit(X_train, y_train)
y_test_proba = final_model.predict_proba(X_test)[:, 1]
y_test_labels = np.where(
    y_test_proba > 0.2, 1, 0
)
# np.array(y_test_proba > 0.2, dtype=int)

# %%
show_proba_calibration_plots(y_test_pred_probs[:, 1], y_test)

# %% [markdown]
# ### Важность признаков<a class="anchor" id="feature_importances"></a>

# %%
X_train_bad_feature = 10*y_train + np.random.randn(y_train.shape[0])
X_train_bad = pd.concat([X_train, X_train_bad_feature], axis=1)

X_train_bad.head(n=2)
# Out:
#       LIMIT_BAL  AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 2886    50000.0   35    41970.0    31319.0    18172.0    18687.0    19234.0
# 8900    50000.0   30    46791.0    42675.0    34256.0    30723.0    19766.0
#
#       BILL_AMT6  PAY_AMT1  PAY_AMT2  ...  PAY_4_3  PAY_5_-1  PAY_5_0  PAY_5_2  \
# 2886    19552.0    1291.0    1303.0  ...        0         0        1        0
# 8900    20449.0    1593.0    1855.0  ...        0         0        1        0
#
#       PAY_5_3  PAY_6_-1  PAY_6_0  PAY_6_2  PAY_6_3  NEXT_MONTH_DEFAULT
# 2886        0         0        1        0        0           -1.259208
# 8900        0         0        1        0        0            0.119093
#
# [2 rows x 52 columns]

# %%
# Плохой пример, использование недопустимого признака при обучении модели

final_model.fit(X_train_bad, y_train)
important_features_top = show_feature_importances(X_train_bad.columns, final_model.feature_importances_, get_top=25)

# %%
final_model.fit(X_train, y_train)
important_features_top = show_feature_importances(X_train.columns, final_model.feature_importances_, get_top=25)

# %%
important_features_top
# Out:
# ['PAY_1_2',
#  'LIMIT_BAL',
#  'PAY_2_2',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_3_2',
#  'BILL_AMT1',
#  'PAY_AMT4',
#  'PAY_AMT3',
#  'PAY_AMT6',
#  'BILL_AMT3',
#  'PAY_5_2',
#  'PAY_1_3',
#  'BILL_AMT4',
#  'PAY_AMT5',
#  'PAY_4_2',
#  'BILL_AMT5',
#  'BILL_AMT2',
#  'PAY_6_2',
#  'AGE',
#  'BILL_AMT6',
#  'EDUCATION_5',
#  'PAY_1_0',
#  'PAY_2_3',
#  'MARRIAGE_2']

# %% [markdown]
# ### Финальная модель<a class="anchor" id="final_model"></a>

# %%
final_model = catb.CatBoostClassifier(n_estimators=500, max_depth=3, l2_leaf_reg=10,
                                      silent=True, random_state=21)
final_model.fit(X_train[important_features_top], y_train)

y_train_pred = final_model.predict(X_train[important_features_top])
y_test_pred = final_model.predict(X_test[important_features_top])
y_test_pred_probs = final_model.predict_proba(X_test[important_features_top])

get_classification_report(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      5852
#            1       0.69      0.36      0.48      1648
#
#     accuracy                           0.82      7500
#    macro avg       0.77      0.66      0.69      7500
# weighted avg       0.81      0.82      0.80      7500
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      1953
#            1       0.71      0.35      0.47       547
#
#     accuracy                           0.83      2500
#    macro avg       0.78      0.66      0.69      2500
# weighted avg       0.81      0.83      0.80      2500
#
# CONFUSION MATRIX
#
# col_0                  0    1
# NEXT_MONTH_DEFAULT
# 0                   1875   78
# 1                    353  194

# %% [markdown]
# ### Сохранение финальной модели<a class="anchor" id="final_model_saving"></a>

# %%
with open("./model.pkl", 'wb') as file:
    pickle.dump(final_model, file)

# %% [markdown]
# ## Курсовой проект

# %% [markdown]
# **Задача**
#
# Требуется, на основании имеющихся данных о клиентах банка, построить модель, используя обучающий датасет, для прогнозирования невыполнения долговых обязательств по текущему кредиту. Выполнить прогноз для примеров из тестового датасета.
#
# **Наименование файлов с данными**
#
# course_project_train.csv - обучающий датасет<br>
# course_project_test.csv - тестовый датасет
#
# **Целевая переменная**
#
# Credit Default - факт невыполнения кредитных обязательств
#
# **Метрика качества**
#
# F1-score (sklearn.metrics.f1_score)
#
# **Требования к решению**
#
# *Целевая метрика*
# * F1($\beta$ = 1) > 0.5 при Precision > 0.5 и Recall > 0.5
# * Метрика оценивается по качеству прогноза для главного класса (1 - просрочка по кредиту)
#
# *Решение должно содержать*
# 1. Тетрадка Jupyter Notebook с кодом Вашего решения, названная по образцу {ФИО}\_solution.ipynb, пример SShirkin\_solution.ipynb
# 2. Файл CSV с прогнозами целевой переменной **(0 или 1, а НЕ вероятность)** для тестового датасета, названный по образцу {ФИО}\_predictions.csv, пример SShirkin\_predictions.csv
#
# *Рекомендации для файла с кодом (ipynb)*
# 1. Файл должен содержать заголовки и комментарии (markdown)
# 2. Повторяющиеся операции лучше оформлять в виде функций
# 3. Не делать вывод большого количества строк таблиц (5-10 достаточно)
# 4. По возможности добавлять графики, описывающие данные (около 3-5)
# 5. Добавлять только лучшую модель, то есть не включать в код все варианты решения проекта
# 6. Скрипт проекта должен отрабатывать от начала и до конца (от загрузки данных до выгрузки предсказаний)
# 7. Весь проект должен быть в одном скрипте (файл ipynb).
# 8. Допускается применение библиотек Python и моделей машинного обучения,
# которые были в данном курсе.
#
# **Сроки сдачи**
#
# Cдать проект нужно в течение 5 дней после окончания последнего вебинара.
# Оценки работ, сданных до дедлайна, будут представлены в виде рейтинга, ранжированного по заданной метрике качества.
# Проекты, сданные после дедлайна или сданные повторно, не попадают в рейтинг, но можно будет узнать результат.
